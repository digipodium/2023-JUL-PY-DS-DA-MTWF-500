# %%
import requests

# %%
url = 'https://www.flipkart.com/search?q=bags&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
response = requests.get(url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text)
print(soup)

# %%
soup.title

# %%
soup.find('a')

# %%
soup.findAll('a')

# %%
print(soup.text)

# %%
links = soup.findAll('a')
for link in links:
    print(link.text)
    print(link.get('href'))

# %%
rows = soup.find_all('div', class_ = '_1AtVbE col-12-12')
print(len(rows))
# Out:
# 15

# %%
total_elements = 0
for row in rows:
    items = row.find_all('div', class_ = '_1xHGtK _373qXS')
    for item in items:
        total_elements += 1
        link  = item.find('a', class_ = '_2UzuFa')
        container = item.find('div', '_2B099V')
        sponsored = container.find('div', class_='_2I5qvP')
        brand = container.find('div', class_='_2WkVRV')
        title = container.find('a', class_='IRpwTa')
        price = container.find('div', class_='_30jeq3')
        oprice = container.find('div', class_='_3I9_wc')
        discount = container.find('div', class_='_3Ay6Sb')
        delivery = container.find('div', class_='_2Tpdn3')
        deal_type = container.find('div', class_='_2Tpdn3 _18hQoS')
        if sponsored:
            print("ad",sponsored.text)
        print("brand", brand.text)  
        print("title", title.get('title'))
        print("price",price.text)
        print("oprice",oprice.text)
        print("discount",discount.text)
        print("delivery",delivery.text)
        print('-'*50)
print(total_elements)
# Out:
# ad Sponsored
# brand Top boTTom
# title Small 10 L Backpack quechua bag casual water resistant backpack for men and women-Blue
# price ₹253
# oprice ₹1,095
# discount 76% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand M
# title Large 60 L Laptop Backpack Stylish Travel Backpack
# price ₹569
# oprice ₹2,999
# discount 81% off
# delivery Free delivery
# --------------------------------------------------
# brand SAFARI
# title Small 15 L Backpack DAYPACK
# price ₹149
# oprice ₹799
# discount 81% off
# delivery Delivery by
# --------------------------------------------------
# brand AMERICAN TOURISTER
# title 32.5 L Backpack Fizz Sch Bag
# price ₹1,150
# oprice ₹2,300
# discount 50% off
# delivery Free delivery by
# --------------------------------------------------
# brand SKYBAGS
# title 21.65 L Backpack BRAT
# price ₹669
# oprice ₹2,100
# discount 68% off
# delivery Free delivery by
# --------------------------------------------------
# brand SAFARI
# title Large 38 L Backpack 19 CASUAL BACKPACK BLUE
# price ₹900
# oprice ₹2,348
# discount 61% off
# delivery Free delivery by
# --------------------------------------------------
# brand A Little Swag
# title Small 12 L Backpack BM-Latch_combo of 2 red mickey, yellow pikachu_1625
# price ₹499
# oprice ₹999
# discount 50% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand Top boTTom
# title Large 35 L Laptop Backpack Quechua bag/Casual Water Resistant Backpack (PK OF -2Combo) For Men and Women
# price ₹849
# oprice ₹1,999
# discount 57% off
# delivery Free delivery
# --------------------------------------------------
# brand SAFARI
# title Large 35 L Backpack Clan
# price ₹1,000
# oprice ₹3,399
# discount 70% off
# delivery Free delivery by
# --------------------------------------------------
# brand SKYBAGS
# title Medium 27 L Backpack Fuse 27L Backpack Green
# price ₹802
# oprice ₹2,000
# discount 59% off
# delivery Free delivery by
# --------------------------------------------------
# ad Sponsored
# brand Modern Style
# title 55 L Laptop Backpack Stylish Printed backpack bags, 55 Litres Trekking bags,Camping bags,Outdoor bags
# price ₹544
# oprice ₹3,199
# discount 82% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand Nida
# title Large 45 L Laptop Backpack Large For School, college, Travel ,Office for Unisex
# price ₹499
# oprice ₹1,999
# discount 75% off
# delivery Free delivery
# --------------------------------------------------
# brand WROGN
# title Large 35 L Laptop Backpack BP/REXINE/1500/BLACK-35L
# price ₹899
# oprice ₹4,999
# discount 82% off
# delivery Free delivery
# --------------------------------------------------
# brand SKYBAGS
# title Medium 30 L Backpack MARVEL SPIDERMAN SCHOOL BACKPACK 02 RED
# price ₹899
# oprice ₹2,198
# discount 59% off
# delivery Free delivery by
# --------------------------------------------------
# brand SKYBAGS
# title 21.65 L Backpack BRAT
# price ₹699
# oprice ₹2,100
# discount 66% off
# delivery Free delivery by
# --------------------------------------------------
# brand SAFARI
# title Small 15 L Backpack DAYPACK
# price ₹399
# oprice ₹799
# discount 50% off
# delivery Free delivery by
# --------------------------------------------------
# ad Sponsored
# brand PERFECT STAR
# title Large 70 L Backpack 70 L TRAVEL BACKPACK FOR OUTDOOR SPORT HIKING TREKKING BAG CAMPING RUCKSACK
# price ₹716
# oprice ₹2,999
# discount 76% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand STRONG LIFE
# title Large 50 L Backpack Unisex 26×14 Water Resistance backpack for Travel Luggage Hiking Trekking Camping & Rucksack Bag
# price ₹649
# oprice ₹2,999
# discount 78% off
# delivery Free delivery
# --------------------------------------------------
# brand A Little Swag
# title Small 12 L Backpack BM-Latch_combo of 2 yellow pikachu, pink panda_1401
# price ₹499
# oprice ₹999
# discount 50% off
# delivery Free delivery
# --------------------------------------------------
# brand PUMA
# title Medium 25 L Laptop Backpack Academy Backpack
# price ₹1,649
# oprice ₹2,499
# discount 34% off
# delivery Free delivery by
# --------------------------------------------------
# ad Sponsored
# brand Top boTTom
# title Small 10 L Backpack quechua bag casual water resistant backpack for men and women-Black
# price ₹254
# oprice ₹1,095
# discount 76% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand M
# title Large 49 L Backpack premium quality Travel Backpack for Outdoor Sport Camping Hiking Trekking Bag
# price ₹542
# oprice ₹2,999
# discount 81% off
# delivery Free delivery
# --------------------------------------------------
# brand SKYBAGS
# title Medium 27 L Backpack GRAF 27L BACKPACK BLUE
# price ₹850
# oprice ₹2,000
# discount 57% off
# delivery Free delivery by
# --------------------------------------------------
# brand SKYBAGS
# title Medium 22 L Backpack FLEX 22L BACKPACK CABRET
# price ₹866
# oprice ₹1,975
# discount 56% off
# delivery Free delivery by
# --------------------------------------------------
# brand SKYBAGS
# title Medium 30 L Backpack DISNEY MICKEY SCHOOL BACKPACK 01 BLACK
# price ₹899
# oprice ₹2,198
# discount 59% off
# delivery Free delivery by
# --------------------------------------------------
# brand SKYBAGS
# title Medium 22 L Backpack VOXEL 22L BACKPACK GREEN
# price ₹800
# oprice ₹1,800
# discount 55% off
# delivery Free delivery by
# --------------------------------------------------
# ad Sponsored
# brand AMERICAN TOURISTER
# title Medium 28 L Backpack BOUNCE
# price ₹1,049
# oprice ₹2,180
# discount 51% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand AMERICAN TOURISTER
# title Medium 28 L Backpack BOUNCE
# price ₹1,099
# oprice ₹2,180
# discount 49% off
# delivery Free delivery
# --------------------------------------------------
# brand Wildcraft
# title Small 17 L Backpack Zeal
# price ₹900
# oprice ₹1,799
# discount 49% off
# delivery Free delivery by
# --------------------------------------------------
# brand Flycraft
# title Medium 30 L Laptop Backpack simna.1550/1 navy blue yellow casual unisex travel, office, massenger,school backpack
# price ₹499
# oprice ₹1,599
# discount 68% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand TRAVEL POINT
# title Medium 25 L Laptop Backpack for Office/College/School/Travel
# price ₹569
# oprice ₹2,999
# discount 81% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand LAXELLA
# title Medium 25 L Laptop Backpack Casual Waterproof Laptop/Office/School/College/Unisex Travel Backpack
# price ₹404
# oprice ₹1,999
# discount 79% off
# delivery Free delivery
# --------------------------------------------------
# brand AMERICAN TOURISTER
# title Large 32 L Backpack POPIN CASUAL BACKPACK 02 - BLACK
# price ₹1,200
# oprice ₹2,590
# discount 53% off
# delivery Free delivery by
# --------------------------------------------------
# brand SKYBAGS
# title Large 31 L Backpack RIDDLE
# price ₹1,050
# oprice ₹2,598
# discount 59% off
# delivery Free delivery by
# --------------------------------------------------
# brand A Little Swag
# title Small 12 L Backpack BM-pink minnie_1094
# price ₹349
# oprice ₹999
# discount 65% off
# delivery Free delivery
# --------------------------------------------------
# brand NorthZone
# title Medium 30 L Backpack Neavy
# price ₹672
# oprice ₹1,999
# discount 66% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand Gear
# title Small 17 L Backpack SUPERIOR XL BACKPACK
# price ₹749
# oprice ₹1,199
# discount 37% off
# delivery Free delivery
# --------------------------------------------------
# ad Sponsored
# brand Top boTTom
# title Small 10 L Backpack quechua bag casual water resistant backpack for men and women-Green
# price ₹253
# oprice ₹1,095
# discount 76% off
# delivery Free delivery
# --------------------------------------------------
# brand Red Lemon
# title Medium 26 L Laptop Backpack Swiss Cut Design 15.6 Inch Laptop Backpack With USB Charging Port for Men Women
# price ₹1,899
# oprice ₹4,999
# discount 62% off
# delivery Free delivery by
# --------------------------------------------------
# brand PUMA
# title Small 18 L Backpack Plus Backpack IND
# price ₹899
# oprice ₹1,499
# discount 40% off
# delivery Free delivery
# --------------------------------------------------
# 40
